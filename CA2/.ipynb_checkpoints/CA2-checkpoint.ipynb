# %%
from PIL import Image, ImageTk
import tkinter as tk 
from tkinter import messagebox 

food_prices = {
    "JOLLOF RICE": 350,
    "COCONUT FRIED RICE": 350,
    "JOLLOF SPAGHETTI": 350,
    "SWEET CHILI CHICKEN": 1100,
    "GRILLLED CHICKEN": 400,
    "FRIED BEEF": 400,
    "FRIED FISH": 500,
    "BOILED EGG": 200,
    "SAUTEED SAUSAGES": 200,
    "SAVOURY BEANS": 350,
    "ROASTED SWEET POTATOES": 300,
    "FRIED PLANTAINS": 150,
    "MIXED VEGETABLES SALAD": 150,
    "BOILED YAM": 150,
    "EBA": 100,
    "POUNDO YAM": 100,
    "SEMO": 100,
    "ATAMA SOUP": 450,
    "EGUSI SOUP": 480,
    "WATER": 200,
    "GLASS DRINK(35CL)": 150,
    "PET DRINK(35CL)": 300,
    "PET DRINK(50CL)": 350,
    "GLASS/CANNED MALT": 500,
    "FRESH YO": 600,
    "PINEAPPLE JUICE": 350,
    "MANGO JUICE": 350,
    "ZOBO DRINK": 350
}

def menu_open():
    menu_window = tk.Toplevel(root)
    menu_window.title("PAU CAFETERIA MENU")
    menu_window.geometry("350x625")
    Menu = "C:/Users/easyf/Downloads/Screenshot_23-4-2024_20274_panatlanticuniversity-my.sharepoint.com.jpeg"
    pic = Image.open(Menu)
    tk_pic = ImageTk.PhotoImage(pic)
    label = tk.Label(menu_window, image=tk_pic)
    label.Menu_Image = tk_pic
    label.pack(pady=10)
    enter_button = tk.Button(menu_window, text="PLACE ORDER", command=lambda:[order_page(), menu_window.destroy()])
    enter_button.pack()

def order_page():
    order = tk.Tk()
    order.title("PAU CAFETERIA")
    order.geometry("400x500")
    name = tk.Label(order, text="Customer Name:")
    name.pack()
    name_entry = tk.Entry(order)
    name_entry.pack()
    carb_button = tk.Button(order, text="RICE/PASTA",command=carb)
    carb_button.pack(pady=15)
    protein_button = tk.Button(order, text="PROTEINS",command=protein )
    protein_button.pack(pady=15)
    swallow_button = tk.Button(order, text="SOUPS & DISHES",command=swallow )
    swallow_button.pack(pady=15)
    side_button = tk.Button(order, text="SIDES DISHES",command=side )
    side_button.pack(pady=15)
    bev_button = tk.Button(order, text="BEVERAGES", command=beverages)
    bev_button.pack(pady=15)

def carb():
    carb_page = tk.Toplevel()
    carb_page.title("RICE/PASTA PAGE")
    carb_page.geometry("300x300")
    jollof_button = tk.Button(carb_page, text="JOLLOF RICE", command=amount)
    jollof_button.pack(pady=10)
    pasta_button = tk.Button(carb_page, text="PASTA", command=amount)
    pasta_button.pack(pady=10)
    fried_button = tk.Button(carb_page, text="COCONUT FRIED RICE", command=amount)
    fried_button.pack(pady=10)

def protein():
    protein_page = tk.Toplevel()
    protein_page.title("PROTEIN PAGE")
    protein_page.geometry("300x300")
    sweet_button = tk.Button(protein_page, text="SWEET CHILLI CHICKEN", command=amount)
    sweet_button.pack(pady=10)
    
    grill_button = tk.Button(protein_page, text="GRILLED CHICKEN WINGS", command=amount)
    grill_button.pack(pady=10)
    friedbeef_button = tk.Button(protein_page, text="FRIED BEEF", command=amount)
    friedbeef_button.pack(pady=10)
    friedfish_button = tk.Button(protein_page, text="FREID FISH", command=amount)
    friedfish_button.pack(pady=10)
    boiled_button = tk.Button(protein_page, text="BOILED EGGS", command=amount)
    boiled_button.pack(pady=10)
    sauteed_button = tk.Button(protein_page, text="SAUTEED SAUSAGES", command=amount)
    sauteed_button.pack(pady=10)

def side():
    side_page = tk.Toplevel()
    side_page.title("SIDES PAGE")
    side_page.geometry("300x300")
    savoury_button = tk.Button(side_page, text="SAVOURY BEANS", command=amount)
    savoury_button.pack(pady=10)
    roast_button = tk.Button(side_page, text="ROASTED SWEET POTATOES", command=amount)
    roast_button.pack(pady=10)
    mixed_button = tk.Button(side_page, text="MIXED VEGETABLES", command=amount)
    mixed_button.pack(pady=10)
    boiledyam_button = tk.Button(side_page, text="BOILED YAM", command=amount)
    boiledyam_button.pack(pady=10)
    friedplan_button = tk.Button(side_page, text="FRIED PLANTAIN", command=amount)
    friedplan.pack(pady=10)

def swallow():
    swallow_page = tk.Toplevel()
    swallow_page.title("SIDES PAGE")
    swallow_page.geometry("300x300")
    eba_button = tk.Button(swallow_page, text="EBA", command=amount)
    eba_button.pack(pady=10)
    poundo_button = tk.Button(swallow_page, text="POUNDO YAM", command=amount)
    poundo_button.pack(pady=10)
    atama_button = tk.Button(swallow_page, text="ATAMA SOUP", command=amount)
    atama_button.pack(pady=10)
    egusi_button = tk.Button(swallow_page, text="EGUSI SOUP", command=amount)
    egusi_button.pack(pady=10)

def beverages():
    bev_page = tk.Toplevel()
    bev_page.title("SIDES PAGE")
    bev_page.geometry("500x500")
    water_button = tk.Button(bev_page, text="WATER", command=amount)
    water_button.pack(pady=10)
    glass_button = tk.Button(bev_page, text="GLASS DRINK (35CL)", command=amount)
    glass_button.pack(pady=10)
    pet1_button = tk.Button(bev_page, text="PET DRINK (35CL)", command=amount)
    pet1_button.pack(pady=10)
    pet2_button = tk.Button(bev_page, text="PET DRINK (50CL)", command=amount)
    pet2_button.pack(pady=10)
    malt_button = tk.Button(bev_page, text="GLASS/CANNED MALT", command=amount)
    malt_button.pack(pady=10)
    fresh_button = tk.Button(bev_page, text="FRESH YO", command=amount)
    fresh_button.pack(pady=10)
    pin_button = tk.Button(bev_page, text="PINEAPPLE JUICE", command=amount)
    pin_button.pack(pady=10)
    mango_button = tk.Button(bev_page, text="MANGO JUICE", command=amount)
    mango_button.pack(pady=10)
    zobo_button = tk.Button(bev_page, text="ZOBO DRINK", command=amount)
    zobo_button.pack(pady=10)

def calculate_total():
        quantity = int(label_3_entry.get())
        price_of_food = food_prices[item_name]
        total_price = quantity * price_of_food
        messagebox.showinfo("Total amount", f"Total amount for {item_name}:" % total_price)
def amount(item_name):   
    quantity = tk.Toplevel()
    quantity.title("Quantity Page")
    quantity.geometry("200x200")
    label_3 = tk.Label(quantity, text="HOW MANY DO YOU WANT?")
    label_3.pack()
    label_3_entry = tk.Entry(quantity)
    label_3_entry.pack()
    finish = tk.Button(quantity, text="ORDER", command=calculate_total)
    finish.pack(pady=10)

 



    
    


    

    


    
    
    
    
    




#Create a window for the image


root = tk.Tk()
root.title("PAU CAFETERIA")
root.geometry("315x100")
label_1 = tk.Label(root, text="WELCOME TO PAU CAFETARIA\nWHERE DELICACIES ARE SERVED FRESH AND HOT AND AT \n A GO!!!")
label_1.pack()
label_1.config(bg="gold")
root.config(bg = "gold")
go_button = tk.Button(root, text="ENTER", command=menu_open)
go_button.pack()

 
    



root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
# TypeError: amount() missing 1 required positional argument: 'item_name'

# %% [markdown]
# #

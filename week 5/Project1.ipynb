# %%
import tkinter as tk
from tkinter import messagebox

emp = {
    "Abu Peter" : "Human Resources",
    "Obasuyi Russell" : "CEO",
    "Ojezua Micheal" : "CSO",
    "Obadiora Christian" : "Driver",
    "Irabor Allen" : "Cleaner",
    "Oketade Tobi" : "Cleaner" ,
    "Agbons Darlington" : "Human Resources" ,
    "Julius Kelma" : "Driver" ,
    "Imafidon Ken" : "Gateman" ,
    "Okhipo Jeshurun" : "Gateman" ,
    "Obazee Esmond" : "Driver" ,
    "Abu Epiphany" : "Driver" ,
    "Uazama Wisdom" : "Chief Accountant" ,
    "Lawani Francis" : "Manager",
    "Onunu Richard" : "MD" ,
    "Siakpere Tekwve" : "Accountant" ,
    "Ighodaye Immanuel" : "Mechanic" ,
    "Etemu Lewis" : "Electrician" ,
    "Ekomwenren Nosa" : "Mechanic" ,
    "Odigie David" : "Driver" ,
    "Odiase Divine" : "Receptionist" ,
    "Abdul Razaq" : "Receptionist" ,
    "Joe Obed" : "Driver" ,
    "Osaigbovo Daniel" : "Administration" ,
    "Ogbebor Osa" : "Adminstration" ,
    "Imakhu Kevin" : "Security" ,
    "Forgive Asia" : "Reception" ,
    "Asemota Daniel" : "Security Guard" ,
    "Shaka Donaldson" : "Logistics Manager" ,
    "Osarenkhoe Eloghosa" : "Transportation Manager" ,
    "Oligbi Stephen" : "Security Guard" ,
    "Oboite Mike" : "Records Manager" ,
    "Akah Byron" : "Security Guard" ,
    "Ezefediba Tobe" : "Cleaner" ,
    "Echeatabu Daniel" : "Mechanic" ,
    "Edowonyi Philip" : "Adminstration" ,
    "Akeno Emmanuel"  : "Administration" ,
    "Edowonyi Philipo" : "Customer Support" ,
    "Ekemezie Ifediri" : "Customer Support" ,
    "Oisakede Darlinghton" : "Customer Support" }

def enter(employee):
    print(emp)
 # Create a main window
root = tk.Tk()
root.title("Login Page")
root.geometry("800x400")
    
label_1 = tk.Label(root, text=f"Welcome to GIG logistics login Platform \n")
label_1.pack()




def submit():
    employee = employee_entry.get()
    department = department_entry.get()
    if employee in emp and emp[employee] == department:
        enter(employee)
        
    else:
        messagebox.showerror("Login", "Invalid Employe name or Department")
    


#Add a button widget
button = tk.Button(root, text="Login", command=submit)
button.pack()
#create an employee and department entry
employee_label = tk.Label(root, text="Employee Name:")
employee_label.pack()
employee_entry = tk.Entry(root)
employee_entry.pack()

department_label = tk.Label(root, text="Department:")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()

root.mainloop()
